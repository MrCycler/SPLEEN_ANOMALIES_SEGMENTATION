# %% [markdown]
# # Script para extraer las imagenes a partir de archivos de ecografia 3D
# ## Entorno de ejecución: Colab
# ## Autor: Juan M. Mendoza

# %%
# Descarga el dataset
# !gdown "https://drive.google.com/uc?export=download&id=1jzeNU1EKnK81PyTsrx0ujfNl-t0Jo8uE"
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1jzeNU1EKnK81PyTsrx0ujfNl-t0Jo8uE
# To: /content/Task09_Spleen.tar
# 1.61GB [00:08, 185MB/s]

# %%
# Descomprime las imagenes
# !tar -xf Task09_Spleen.tar

# %%
import glob
import re

#obtiene los paths para entrenamiento
paths_tr = glob.glob("Task09_Spleen/imagesTr/*.nii.gz")
numbers_tr = list(map(lambda x: str(int(re.search(r'\d+', x.split('spleen_')[1]).group(0))), paths_tr))

#obtiene los paths para validacion
paths_ts = glob.glob("Task09_Spleen/imagesTs/*.nii.gz")
numbers_ts = list(map(lambda x: str(int(re.search(r'\d+', x.split('spleen_')[1]).group(0))), paths_ts))

# %%
# https://github.com/alexlaurence/NIfTI-Image-Converter/blob/master/python/nii2png.py
import convert_v2 as cvt

#extrae las imagenes de training y las guarda en la carpeta
for i in range(len(paths_tr)):
  cvt.convert(paths_tr[i],'images_tr/'+numbers_tr[i])

#extrae las imagenes de test y las guarda en la carpeta
for j in range(len(paths_ts)):
  cvt.convert(paths_ts[j],'images_ts/'+numbers_ts[j])
# Out:
# Input file is  Task09_Spleen/imagesTr/spleen_24.nii.gz
# Output folder is  images_tr/24
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1024.0, 1502.0]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1024.0, 1495.0]. Convert image to uint8 prior to saving to suppress this warning.
# 3
# Created ouput directory: images_tr/24
# Reading NIfTI file...
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1024.0, 1432.0]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [-1024.0, 1501.0]. Convert image to uint8 prior to saving to suppress this warning.
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# ...

# %%
# instala el compresor
# !apt-get install rar
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   rar
# 0 upgraded, 1 newly installed, 0 to remove and 33 not upgraded.
# Need to get 295 kB of archives.
# After this operation, 799 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 rar amd64 2:5.5.0-1 [295 kB]
# Fetched 295 kB in 1s (510 kB/s)
# Selecting previously unselected package rar.
# (Reading database ... 144379 files and directories currently installed.)
# Preparing to unpack .../rar_2%3a5.5.0-1_amd64.deb ...
# Unpacking rar (2:5.5.0-1) ...
# Setting up rar (2:5.5.0-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# comprime los archivos
# !rar a "images_tr" "images_tr"
# !rar a "images_ts" "images_ts"
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...
